# %%
import pandas as pd

df = pd.read_csv(r'C:\Users\user\ML\Regression\energy-efficiency\ENB2012_data - heating.csv')
df
# Out:
#      Relative Compactness  Surface Area  Wall Area  Roof Area  Overall Height  \
# 0                    0.98         514.5      294.0     110.25             7.0
# 1                    0.98         514.5      294.0     110.25             7.0
# 2                    0.98         514.5      294.0     110.25             7.0
# 3                    0.98         514.5      294.0     110.25             7.0
# 4                    0.90         563.5      318.5     122.50             7.0
# ..                    ...           ...        ...        ...             ...
# 763                  0.64         784.0      343.0     220.50             3.5
# 764                  0.62         808.5      367.5     220.50             3.5
# 765                  0.62         808.5      367.5     220.50             3.5
# 766                  0.62         808.5      367.5     220.50             3.5
# 767                  0.62         808.5      367.5     220.50             3.5
#
#      Orientation  Glazing Area  Glazing Area Distribution  Heating Load
# 0              2           0.0                          0         15.55
# 1              3           0.0                          0         15.55
# 2              4           0.0                          0         15.55
# 3              5           0.0                          0         15.55
# 4              2           0.0                          0         20.84
# ..           ...           ...                        ...           ...
# 763            5           0.4                          5         17.88
# 764            2           0.4                          5         16.54
# 765            3           0.4                          5         16.44
# 766            4           0.4                          5         16.48
# 767            5           0.4                          5         16.64
#
# [768 rows x 9 columns]

# %%
from RegressionAssumptionsChecker import RegressionAssumptionsChecker
checker = RegressionAssumptionsChecker(df, target="Heating Load", algorithm="LinearRegression")

assumptions = checker.check_assumptions()
checker.report_assumptions()
#print("Assumption check:", assumptions)
# Out:
# 🔍 Assumption Diagnostics Report
# ========================================
#
# 🧠 Linearity
# ------------------------------
# linearity: False
# p_value: 9.914145717204721e-14
# notes: Non-linearity detected.
#
# 🧠 Multicollinearity
# ------------------------------
# multicollinearity: False
# details: [{'feature': 'Roof Area', 'VIF': 5.245242453059276}, {'feature': 'Overall Height', 'VIF': 4.5449444712642935}, {'feature': 'Glazing Area', 'VIF': 4.284221829015403}, {'feature': 'Glazing Area Distribution', 'VIF': 4.4854730963260945}]
# notes: Perfect or high multicollinearity detected
# recommendation: High or perfect multicollinearity detected. Consider removing these features: ['Surface Area', 'Relative Compactness', 'Wall Area', 'Orientation']
# drop_set: ['Surface Area', 'Relative Compactness', 'Wall Area', 'Orientation']
#
# 🧠 Heteroscedasticity
# ------------------------------
# homoscedasticity: False
# p_value: 4.981729702890193e-62
# notes: Residuals are heteroscedastic.
#
# 🧠 Status
# ------------------------------
# unsuitable
#
# 🧠 Reason
# ------------------------------
# LinearRegression is not suitable because residuals are heteroscedastic. Consider robust alternatives such as HuberRegressor or RANSACRegressor.

# %%
df = pd.DataFrame({
    "x1": [1,2,3,4,5],
    "x2": [2,4,6,8,10],
    "x3": [2,4,6,8,10],
    "x4": [2,6,4,8,10],
    "y":  [1,2,1.5,3,2.5]
})

from RegressionAssumptionsChecker import RegressionAssumptionsChecker
checker = RegressionAssumptionsChecker(df, target="y", algorithm="KNeighborsRegressor")

checker.check_assumptions()
checker.report_assumptions()
# Out:
# 🔍 Assumption Diagnostics Report
# ========================================
#
# 🧠 Status
# ------------------------------
# conditionally_permissible
#
# 🧠 Reason
# ------------------------------
# Scaling required.

# %%
from RegressionAssumptionsChecker import RegressionAssumptionsChecker
checker = RegressionAssumptionsChecker(df, target="y", algorithm="LinearRegression")

checker.check_assumptions()
checker.report_assumptions()
# Out:
# 🔍 Assumption Diagnostics Report
# ========================================
#
# 🧠 Linearity
# ------------------------------
# linearity: True
# p_value: 0.5961501894160928
# notes: Linearity assumption holds.
#
# 🧠 Multicollinearity
# ------------------------------
# multicollinearity: False
# details: [{'feature': 'x4', 'VIF': None}]
# notes: Perfect or high multicollinearity detected
# recommendation: High or perfect multicollinearity detected. Consider removing these features: ['x1', 'x2', 'x3']
# drop_set: ['x1', 'x2', 'x3']
#
# 🧠 Heteroscedasticity
# ------------------------------
# homoscedasticity: True
# p_value: 0.635255928632028
# notes: Homoscedasticity assumption holds.
#
# 🧠 Status
# ------------------------------
# suitable
